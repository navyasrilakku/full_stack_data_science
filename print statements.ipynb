# %%
print(10)
# Out:
# 10

# %%
print('python')
# Out:
# python

# %%
print(10,20,30)
# Out:
# 10 20 30

# %%
print(10,10.5,'Naresh it', True)
# Out:
# 10 10.5 Naresh it True

# %%
n1=10
n2=20
print(n1,n2)
# Out:
# 10 20

# %%
print(10), print(20) #good
# Out:
# 10
# 20
# (None, None)

# %%
print(10,20,30)
print(10), print(20)
# Out:
# 10 20 30
# 10
# 20
# (None, None)

# %%
n1=10
n1
# Out:
# 10

# %%
print(10)
print(20)
# Out:
# 10
# 20

# %%
print(10,20)
# Out:
# 10 20

# %%
print(10), print(20)
# Out:
# 10
# 20
# (None, None)

# %%
10,20
# Out:
# (10, 20)

# %%
n1=10
n2=20
n1,n2
# Out:
# (10, 20)

# %%
a=100
b=200
c=a+b
#the addition of 10 and 20 is 30
print("the addition of 10 and 20 is 30")

print("the addition of",a, "and", b,"is", c)
# Out:
# the addition of 10 and 20 is 30
# the addition of 100 and 200 is 300

# %% [markdown]
# # format

# %%
a=100
b=200
c=a+b
print("the addition of {} and {} is {}".format(a,b,c))
# Out:
# the addition of 100 and 200 is 300

# %%
#read your name
#read your age
#read your city
#My name is python, Im 10 years ols, Im from hyderabad
name="python"
age=10
city='hyd'
print("My name is {} , im {} years old, Im from {}".format(name,age,city))
# Out:
# My name is python , im 10 years old, Im from hyd

# %%
#employee name
#employee role
# company
name='omkar'
role='DS'
company='Google'
print("My name is {} , I want to become {} , in {} company".format(name,role,company))
# Out:
# My name is omkar , I want to become DS , in Google company

# %% [markdown]
# # f string

# %%
a=100
b-200
c=a+b
print(f"the addition of{a} and {b} is {c}")
# Out:
# the addition of100 and 200 is 300

# %%
name="python"
age=10
city="hyd"
print(f"My name is {name} , my age is {age} , im from {city} ")
# Out:
# My name is python , my age is 10 , im from hyd

# %%
name='omkar'
role='DS'
company='Google'
print(f"My name is {name} , I want to become {role} , in {company} company")
# Out:
# My name is omkar , I want to become DS , in Google company

# %% [markdown]
# # second session on print statements

# %%
print(10)
# Out:
# 10

# %%
print('python')
# Out:
# python

# %%
n='hi, im navya sri'
n
# Out:
# 'hi, im navya sri'

# %%
print(10,10.5,'naresh it', True)
# Out:
# 10 10.5 naresh it True

# %%
n1=10
n2=20
print(n1)
print(n2)
# Out:
# 10
# 20

# %%
print(10, 20, 30)
print(10,20)
print(10)
# Out:
# 10 20 30
# 10 20
# 10

# %%
print(10), print(20)
# Out:
# 10
# 20
# (None, None)

# %% [markdown]
# # Format method

# %%
a=100
b=200
c=a+b
print("the addition of", a, "and", b, "is",c)
# Out:
# the addition of 100 and 200 is 300

# %%
n1='python'
n2=20
n3="hyd"
print("My name is {} , im {} years old, im from {}".format(n1,n2,n3))
# Out:
# My name is python , im 20 years old, im from hyd

# %%
emp_name='navya'
emp_role="data scientist"
emp_company="cognizant"
print("Im {} , my role is {} , im working in {} company".format(emp_name, emp_role,emp_company))
# Out:
# Im navya , my role is data scientist , im working in cognizant company

# %% [markdown]
# # f string method

# %%
a=100
b=200
c=a+b
print(f"the addition of {a} and {b} is {c}")
# Out:
# the addition of 100 and 200 is 300

# %%
n1="python"
n2=20
n3="city"
print(f" im {n1} , im {n2} years old, im from {n3}")
# Out:
#  im python , im 20 years old, im from city

# %%
num1=100
num2=200
avg=(num1+num2)/2
print(f"the avg of {num1} and {num2} is {avg}")
# Out:
# the avg of 100 and 200 is 150.0

# %%
#radius of the circle
#take the pi value=3.14
#find the area of the circle = pi*r*r
rad=10
pi=3.14
area=pi*rad*rad
print("the area of the circle is {}".format(area))
print(f"the area of the circle is {area}")
# Out:
# the area of the circle is 314.0
# the area of the circle is 314.0

# %%
#take the breadth(base) of the traiangle
#take the height of the traingle
#area of the triangle = 1/2*base*height
base=10
height=20
area=1/2*base*height
print("the area of the triangle is {}".format(area))
print(f"the area of the triangle is {area}")
# Out:
# the area of the triangle is 100.0
# the area of the triangle is 100.0

# %%
#take the bill amount
#tak the tip percentage
#calculate the tip amount
#calculate the total bill 10/100*(1000)
#print the total bill
bill_amount=1000
tip_percentage=10
tip_amount=bill_amount*tip_percentage/100
total_bill=tip_amount+bill_amount
print(f"the total bill is:{total_bill}")
# Out:
# the total bill is:1100.0

# %% [markdown]
# # End operator

# %% [markdown]
# - combining multiple statements in a singl line

# %%
print(10,end=' ')
print(20)
# Out:
# 10 20

# %%
print(10,end=' ')
print(20,end=' ')
print(30)
# Out:
# 10 20 30

# %% [markdown]
# # seperator operator

# %% [markdown]
# - separate the multiple values in a singl print statement

# %%
print(10,20,30,sep='&')
# Out:
# 10&20&30

# %%
print(10,20,30,sep='$')
# Out:
# 10$20$30

# %%
print("the addition of {} and {} is {}.".format(5,3,5+3))
# Out:
# the addition of 5 and 3 is 8.

# %%
print("The addition of 5 and 3 is 8",'.')
# Out:
# The addition of 5 and 3 is 8 .

# %%
print("The addition of 5 and 3 is 8",'.',sep='')
# Out:
# The addition of 5 and 3 is 8.
