# %% [markdown]
# **dictionary**
# - we already seen many inbuilt datatypes
# - string
# - list
# - tuple
# - set
# - dictionary(now)

# %% [markdown]
# **zip**

# %%
names=['ramesh','suresh','kamlesh']
age=[20,25,30]
for i,j in zip(names,age):
    print(i,j)
# Out:
# ramesh 20
# suresh 25
# kamlesh 30

# %% [markdown]
# - for combining two lists here we use the zip method
# - based on zip method it automatically form as the key value pair
# - if both lists are in different length zip method will not work

# %%
list(zip(names,age))
# Out:
# [('ramesh', 20), ('suresh', 25), ('kamlesh', 30)]

# %%
tuple(zip(names,age))
# Out:
# (('ramesh', 20), ('suresh', 25), ('kamlesh', 30))

# %%
'ramesh' is the key ========== 20 is its related value
dict1={'ramesh':20,'suresh':25,'kamlesh':30}

# %%
dict1={'ramesh':20,'suresh':25,'kamlesh':30}
dict1
# Out:
# {'ramesh': 20, 'suresh': 25, 'kamlesh': 30}

# %%
type(dict1)
# Out:
# dict

# %%
len(dict1)
# Out:
# 3

# %%
max(dict1)
# Out:
# 'suresh'

# %%
min(dict1)
# Out:
# 'kamlesh'

# %% [markdown]
# **initialization**

# %% [markdown]
# ***create all types of dictionary***

# %%
dic1={'navya':1}
dic1
# Out:
# {'navya': 1}

# %%
dis1={2:7,5:0,4:10}
dis1
# Out:
# {2: 7, 5: 0, 4: 10}

# %%
dis1[2]
# Out:
# 7

# %%
dis1[2]=8

# %%
dis1
# Out:
# {2: 8, 5: 0, 4: 10}

# %%
dict2={3:7,{7:9,{2:0}}}
# Out:
#   File "C:\Users\My world\AppData\Local\Temp\ipykernel_5660\2522234624.py", line 1
#     dict2={3:7,{7:9,{2:0}}}
#                          ^
# SyntaxError: invalid syntax

# %%
dic3={'navya':'lakku','sravya':'sri','anya':'vangya'}
dic3
# Out:
# {'navya': 'lakku', 'sravya': 'sri', 'anya': 'vangya'}

# %%
dic4={True:1,False:2}
dic4
# Out:
# {True: 1, False: 2}

# %%
d3={'ajay':30,'ajay':25}
d3
# Out:
# {'ajay': 25}

# %%
d4={30:'ajay',25:'ajay'}
d4
# Out:
# {30: 'ajay', 25: 'ajay'}

# %%
d2={['navya','sravya']:1}
d2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5660\3739711242.py in <module>
# ----> 1 d2={['navya','sravya']:1}
#       2 d2
#
# TypeError: unhashable type: 'list'

# %%
d2={1:['navya','sravya']}
d2
# Out:
# {1: ['navya', 'sravya']}

# %%
d8={('navya','sravya'):1}
d8
# Out:
# {('navya', 'sravya'): 1}

# %%
d8={1:('navya','sravya')}
d8
# Out:
# {1: ('navya', 'sravya')}

# %%
fruits={'mango':{'mango':25}
fruits
# Out:
#   File "C:\Users\My world\AppData\Local\Temp\ipykernel_5660\864844626.py", line 2
#     fruits
#     ^
# SyntaxError: invalid syntax

# %%
- **keys are important**
- keys only have latest value
- values can b duplicate
-which means different keys can have same value
- list can bot be a key
-tuple can be a key
- keys should be only one

# %%
da={'manish':25,'shuban':20,'govindh':15}
da
# Out:
# {'manish': 25, 'shuban': 20, 'govindh': 15}

# %%
db={'manish':25,'shuban':'20','govindh':15}
db
# Out:
# {'manish': 25, 'shuban': '20', 'govindh': 15}

# %%
dc={'manish':25,'shuban':'20','govindh':15}
dc
# Out:
# {'manish': 25, 'shuban': '20', 'govindh': 15}

# %%
dd={'manish':'25','shuban':'20','govindh':'15'}
dd
# Out:
# {'manish': '25', 'shuban': '20', 'govindh': '15'}

# %%
de={20:'manish',25:'shuban',30:'govindh'}
de
# Out:
# {20: 'manish', 25: 'shuban', 30: 'govindh'}

# %%
df={'manish':20,'shuban':20,'govindh':20}
df
# Out:
# {'manish': 20, 'shuban': 20, 'govindh': 20}

# %%
dg={20:'manish',20:'shuban',20:'govindh'}
dg
# Out:
# {20: 'govindh'}

# %%
max(da)
# Out:
# 'shuban'

# %%
max(dc)
# Out:
# 'shuban'

# %%
min(dc)
# Out:
# 'govindh'

# %%
len(dc)
# Out:
# 3

# %%
k=reversed(dc)

# %%
for i in k:
    print(i)
# Out:
# govindh
# shuban
# manish

# %%
sorted(dc)
# Out:
# ['govindh', 'manish', 'shuban']

# %%
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
'clear',
 'copy',
 'fromkeys',
 'get',
 'items',
 'keys',
 'pop',
 'popitem',
 'setdefault',
 'update',
 'values'

# %% [markdown]
# **reversed**
# - while applying reversed to dictionary, we get onlys keys
# - that keys should be in reverse mode

# %%
dd={'manish':'25','shuban':'20','govindh':'15'}
for i in dd:
    print(i)
# Out:
# manish
# shuban
# govindh

# %%
dd={'manish':'25','shuban':'20','govindh':'15'}
for i in dd:
    print(i)

# %%
'25' in dd
# Out:
# False

# %%
'manish'in dd
# Out:
# True

# %% [markdown]
# **index**

# %%
dd={'manish':'25','shuban':'20','govindh':'15'}
#if we want retrive the values
dd['manish']
# Out:
# '25'

# %%
d10={'fruits':{'mango':20}}
d10
# Out:
# {'fruits': {'mango': 20}}

# %%
#dictionary is a key:value pair
# we can not use index number directly
# whenever you want to call a value, we will use key

# %%
dd['manish']
# Out:
# '25'

# %%
for i in dd:
    print(i,dd[i])
# Out:
# manish 25
# shuban 20
# govindh 15

# %%
for i in dd:
    print(f'{i} has age: {dd[i]}')
# Out:
# manish has age: 25
# shuban has age: 20
# govindh has age: 15

# %%
names=['vignesh','mohit','nagesh']
age=[20,25,30]
for i,j in zip(names,age):
    print(f"{i} has age {j}")
# Out:
# vignesh has age 20
# mohit has age 25
# nagesh has age 30

# %% [markdown]
# **dictonary to list**

# %%
k=[]
v=[]
for i in dd:
    k.append(i)
    v.append(dd[i])
print(k)
print(v)
# Out:
# ['manish', 'shuban', 'govindh']
# ['25', '20', '15']

# %%
keys=[i for i in dd]
values=[dd[i] for i in dd]
print(keys)
print(values)
# Out:
# ['manish', 'shuban', 'govindh']
# ['25', '20', '15']

# %% [markdown]
# **how to create an empty list**
# - l=[]
# - l.append(20)
# - l

# %% [markdown]
# **empty string**

# %% [markdown]
# - s=""
# - s=s+'a'
# - s

# %%
l=[]
l.append(20)
l
# Out:
# [20]

# %%
s=""
s=s+'a'
s
# Out:
# 'a'

# %% [markdown]
# **empty dictionary**

# %%
d={}
d[<key>]=<value>

# %%
d={}
d['navya']=22
d
# Out:
# {'navya': 22}

# %%
d['parthivi']=25
d
# Out:
# {'navya': 22, 'parthivi': 25}

# %%
d['madhra']=21
d
# Out:
# {'navya': 22, 'parthivi': 25, 'madhra': 21}

# %%
name=['navya','parthivi','madhra']
ages=[21,22,23]
namesi={}
agesi={}
for i,j in zip(name,ages):
    namesi[i]=j
namesi
# Out:
# {'navya': 21, 'parthivi': 22, 'madhra': 23}

# %% [markdown]
# **string to list**

# %%
s="hello hai how are you"
s.split()
# Out:
# ['hello', 'hai', 'how', 'are', 'you']

# %%
s1="hello hai hai how how are you"
k=s.split()
d={}
count=0
for i in k:
    d[i]=s1.count(i)
d
# Out:
# {'hello': 1, 'hai': 2, 'how': 2, 'are': 1, 'you': 1}

# %%
#task-1: remove a, an, the, is
#task-2: data science first letter ascii value: 68
#        since first letter ascii value :115
# output :-- {'Data':68, 'science':115}

# %% [markdown]
# **mutable- immutable**

# %% [markdown]
# - change the elements using index
# - but in dictionary there is no index
# - in dictinary we will change the value based on key only
# - instead of using the index, chang the values using key
# - if it is change it is mutable
# - if it is not change it is immutable

# %%
dk={'madhura':20,'maya':40}
dk['madhura']=30
dk
# Out:
# {'madhura': 30, 'maya': 40}

# %% [markdown]
# - list and dictionaruy are mutable
# - tuple strings are immutable
# - difference between list and tuple

# %%
ds={'Fruits':['mango']}
ds['Fruits'][0]
# Out:
# 'mango'

# %%
m={'Fruits':[{'Apple':{'kashmir':['India']}}]}
m['Fruits'][0]['Apple']['kashmir'][0]
# Out:
# 'India'

# %%
s={'fruits':{'banginapalli':{'mango':{'nagpur':{'mh':{'shivaji':{'shambaji'}}}}}}}
m=list(s['fruits']['banginapalli']['mango']['nagpur']['mh']['shivaji'])
m[0]
# Out:
# 'shambaji'

# %%
string1="""Data science is an interdisciplinary academic field that uses statistics, 
scientific computing, scientific methods, processes, scientific visualization, algorithms and systems to extract or
extrapolate knowledge and insights from potentially noisy, structured, or unstructured data.

Data science also integrates domain knowledge from the underlying application domain
(e.g., natural sciences, information technology, and medicine).
Data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.

"""
k=string1.split()
ls=[]
dic={}
for i in k:
    if i not in ("a","an","is","that","the","and"):
        ls.append(i)
        for i in range(len(ls)):
            dic[ls[i]]=ord(ls[i][0])
print(dic,end=" ")
# Out:
# {'Data': 68, 'science': 115, 'interdisciplinary': 105, 'academic': 97, 'field': 102, 'uses': 117, 'statistics,': 115, 'scientific': 115, 'computing,': 99, 'methods,': 109, 'processes,': 112, 'visualization,': 118, 'algorithms': 97, 'systems': 115, 'to': 116, 'extract': 101, 'or': 111, 'extrapolate': 101, 'knowledge': 107, 'insights': 105, 'from': 102, 'potentially': 112, 'noisy,': 110, 'structured,': 115, 'unstructured': 117, 'data.': 100, 'also': 97, 'integrates': 105, 'domain': 100, 'underlying': 117, 'application': 97, '(e.g.,': 40, 'natural': 110, 'sciences,': 115, 'information': 105, 'technology,': 116, 'medicine).': 109, 'multifaceted': 109, 'can': 99, 'be': 98, 'described': 100, 'as': 97, 'science,': 115, 'research': 114, 'paradigm,': 112, 'method,': 109, 'discipline,': 100, 'workflow,': 119, 'profession.': 112}

# %% [markdown]
# **dictionary methods**

# %%
dir(' ')# string methods
dir([])#list methods
dir(())#tuple methods
dir({})#set methods

# %% [markdown]
# **items-keys-values**

# %%
d={'navya':1,'sri':2,'reddy':3}
d.items()
# Out:
# dict_items([('navya', 1), ('sri', 2), ('reddy', 3)])

# %%
d.keys()
# Out:
# dict_keys(['navya', 'sri', 'reddy'])

# %%
d.values()
# Out:
# dict_values([1, 2, 3])

# %%
#we already learn  how to make a list from dictionary

# %%
list(d.keys()),list(d.values())
# Out:
# (['navya', 'sri', 'reddy'], [1, 2, 3])

# %% [markdown]
# - Dictionary  keys will give dictionary keys items in a list
# - it looks like a  list , but it is not a list
# - which means it cannot apply list methods
# - so we need to convert into a list type, by using list type casting

# %%
d={'navya':1,'sri':2,'reddy':3}
l=[]
s=[]
for i in d:
    l.append(i)
    s.append(d[i])
l,s
# Out:
# (['navya', 'sri', 'reddy'], [1, 2, 3])

# %%
for  i in list[d.keys()]:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8148\311110840.py in <module>
# ----> 1 for  i in list[d.keys()]:
#       2     print(i)
#
# TypeError: 'types.GenericAlias' object is not iterable

# %%
list[d.keys()]
# Out:
# list[dict_keys(['navya', 'sri', 'reddy'])]

# %%
list[d.keys()][0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8148\761277331.py in <module>
# ----> 1 list[d.keys()][0]
#
# TypeError: There are no type variables left in list[dict_keys(['navya', 'sri', 'reddy'])]

# %%
list(d.keys())
# Out:
# ['navya', 'sri', 'reddy']

# %%
list(d.keys())[0]
# Out:
# 'navya'

# %%
type(list[d.keys()])
# Out:
# types.GenericAlias

# %% [markdown]
# **method-1**

# %%
d={'navya':1,'sri':2,'reddy':3}
l=[]
s=[]
for i in d:
    l.append(i)
    s.append(d[i])
l,s
# Out:
# (['navya', 'sri', 'reddy'], [1, 2, 3])

# %% [markdown]
# **method-2**

# %%
d={'navya':1,'sri':2,'reddy':3}
list(d.keys()),list(d.values())
# Out:
# (['navya', 'sri', 'reddy'], [1, 2, 3])

# %% [markdown]
# **method-3**

# %%
keys,values=[],[]
for i,j in d.items():
    print(i,j)
    keys.append(i)
    values.append(j)
keys,values
# Out:
# navya 1
# sri 2
# reddy 3
# (['navya', 'sri', 'reddy'], [1, 2, 3])

# %%
dir({})
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %% [markdown]
# **fromkeys**

# %%
#assignment
my_dict = dict.fromkeys(['a', 'b'], 1); 
print(my_dict)
# Out:
# {'a': 1, 'b': 1}

# %% [markdown]
# **get**

# %%
my_dict = {'a': 1, 'b': 2};
print(my_dict.get('a',0))#here '0' is default
# Out:
# 1

# %% [markdown]
# **items**

# %%
my_dict = {'a': 1, 'b': 2};
print(my_dict.items())
# Out:
# dict_items([('a', 1), ('b', 2)])

# %% [markdown]
# **keys**

# %%
my_dict = {'a': 1, 'b': 2};
print(my_dict.keys())
# Out:
# dict_keys(['a', 'b'])

# %% [markdown]
# **pop(key,default)**

# %%
my_dict = {'a': 1, 'b': 2};
print(my_dict.pop('a', 0))
# Out:
# 1

# %%
my_dict
# Out:
# {'b': 2}

# %% [markdown]
# **popitem**

# %%
my_dict = {'a': 1, 'b': 2}; 
print(my_dict.popitem())
# Out:
# ('b', 2)

# %%
my_dict
# Out:
# {'a': 1}

# %% [markdown]
# **clear**

# %%
my_dict = {'a': 1, 'b': 2}
my_dict.clear()

# %%
my_dict
# Out:
# {}

# %% [markdown]
# **copy**

# %%
my_dict = {'a': 1, 'b': 2}
new_dict = my_dict.copy()
print(new_dict)
# Out:
# {'a': 1, 'b': 2}
