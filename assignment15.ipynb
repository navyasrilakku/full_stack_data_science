# %%
# Q2)l1=['Hyd','Mumbai','Chennai','blr']
#  ans=['Mumbai','Chennai']  
#  we want lements which are len of element >4
l1 = ['Hyd', 'Mumbai', 'Chennai', 'blr']

ans = [element for element in l1 if len(element) > 4]

print(ans)
# Out:
# ['Mumbai', 'Chennai']

# %%
# Q3)l1=['Hyd','Mum#bai','Chen#nai','blr']
#  ans=['Mum#bai'',Chen#nai']  
#  we want lements which are having '#'
l1 = ['Hyd', 'Mum#bai', 'Chen#nai', 'blr']

ans = [element for element in l1 if '#' in element]

print(ans)
# Out:
# ['Mum#bai', 'Chen#nai']

# %%
# Q4)l1=['hyd','mumbai','chennai','blr']
#  ans= ['Hyd','Mumbai','Chennai','Blr']
#  we want lements which are len of element >4
l1 = ['hyd','mumbai','chennai','blr']

ans = [element.capitalize() for element in l1 if len(element) > 4]

print(ans)
# Out:
# ['Mumbai', 'Chennai']

# %%
# Q5)l1=['Hyd','Mumbai','chennai','blr']
#  ans= ['Hyd','Mumbai']
#  we want lements which are having first letter capital
l1 = ['Hyd', 'Mumbai', 'chennai', 'blr']

ans = [element for element in l1 if element[0].isupper()]

print(ans)
# Out:
# ['Hyd', 'Mumbai']

# %%
# Q6)l1=['Hyd','Mum#bai','Chen#nai','blr']
#  ans_#=['Mum#bai'',Chen#nai']  
#  ans_without_#=['Hyd'','blr']
#  we want lements which are having '#'
l1 = ['Hyd', 'Mum#bai', 'Chen#nai', 'blr']

ans_with_ = [element for element in l1 if '#'  in element]
ans_without_ = [element for element in l1 if '#' not in element]

print(ans_with_)
print(ans_without_)
# Out:
# ['Mum#bai', 'Chen#nai']
# ['Hyd', 'blr']

# %%
# Q7) ask the user get 5 numbers randomly
#     even_list and odd_list
#     even numbers should append at even_list
#     odd number should append at odd_list
even_list = []
odd_list = []

for i in range(5):
    num = int(input("Enter a number: "))
    if num % 2 == 0:
        even_list.append(num)
    else:
        odd_list.append(num)

print("Even list: ", even_list)
print("Odd list: ", odd_list)
# Out:
# Enter a number: 6
# Enter a number: 2
# Enter a number: 7
# Enter a number: 4
# Enter a number: 9
# Even list:  [6, 2, 4]
# Odd list:  [7, 9]

# %%
# Q8) str='hello hai how are you'
# Maximum len of word using split and max method
# sum of all the indexes of the maximum len of word using append
str = 'hello hai how are you'

words = str.split()  
max_len = max(len(word) for word in words)  

max_len_words = [word for word in words if len(word) == max_len]  
indexes = [words.index(word) for word in max_len_words] 

sum_of_indexes = sum(indexes)  

print(f"Maximum length of a word: {max_len}")
print(f"Words with maximum length: {max_len_words}")
print(f"Sum of indexes: {sum_of_indexes}")
# Out:
# Maximum length of a word: 5
# Words with maximum length: ['hello']
# Sum of indexes: 0

# %%
# Q9) str1='virat.kohli@rcb.com, Rohit.sharma@mi.co, KL.Rahul@lucknow.com'
# Firstname=[]  second name=[]  cname =[]
# append first name should be in first name list
#        second name shoul be in second name list
#        thirs name will be in thirs name list
str1 = 'virat.kohli@rcb.com, Rohit.sharma@mi.co, KL.Rahul@lucknow.com'

firstname = []
secondname = []
cname = []

for email in str1.split(','):
    email = email.strip()  
    name, domain = email.split('@')
    first, second = name.split('.')
    firstname.append(first)
    secondname.append(second)
    cname.append(domain.split('.')[0])

print(firstname)  
print(secondname) 
print(cname)
# Out:
# ['virat', 'Rohit', 'KL']
# ['kohli', 'sharma', 'Rahul']
# ['rcb', 'mi', 'lucknow']

# %%
# 10 )
#  You have two lists
# qns=['What is capital of India',
#       'Who is PM of india',
#        'Who is ICT ODI captian']
# ans = ['Delhi','Modi','Rohit']

# For i in qns:
#     print(i)
#     ans= delhi
#      index should match
#      delhi  modi
#      marks= marks+1
# print the total marks
qns=['What is capital of India', 'Who is PM of india', 'Who is ICT ODI captain']
ans = ['Delhi','Modi','Rohit']
marks = 0

for i in range(len(qns)):
    print(qns[i])
    user_ans = input("Enter answer: ")
    if user_ans.lower() == ans[i].lower():
        print("Correct!")
        marks += 1
    else:
        print(f"Sorry, the correct answer is {ans[i]}")

print(f"Total marks: {marks}/{len(qns)}")
# Out:
# What is capital of India
# Enter answer: delhi
# Correct!
# Who is PM of india
# Enter answer: modi
# Correct!
# Who is ICT ODI captain
# Enter answer: dhoni
# Sorry, the correct answer is Rohit
# Total marks: 2/3
