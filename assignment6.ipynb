# %%
def multiply(a,b=10):
   
    mul=a*b
    print(mul)
multiply(5)
#first we are defining the function
#while defining the function we have b=10
#now we are calling the function
#running function with the values a=5 and b=10
# Out:
# 50

# %%
def multiply(a,b=10):
    
    mul=a*b
    print(mul)
multiply(5,5)
#first we are defining th function
#while defining the function we have b=10
#now we are calling the function with the latest value b=5
#while running the function it shows the output with the latest value
# Out:
# 25

# %%
def multiply(a,b=10):
    b=3
    mul=a*b
    print(mul)
multiply(5,5)
#while defining the function the value b=10
#while it is calling the latest value of b=5
# while running the function the latest value b=3
# Out:
# 15

# %%
def multiply(a,b=10):
    b=3
    mul=a*b
    print(mul)
b=2
multiply(5,5)
#while defining the function b=10
#the value of b changed as b=2
#while calling the function the value b=5
#whil running it changed  b=3
# Out:
# 15

# %%
a=10
b=20
def multiply(a=5):  
    mul=a*b
    print(mul)
multiply()
#the global value of a=10
#while defining the function the valu changed as a=5
#while calling the function a=5
#while running the function a=5
# Out:
# 100

# %%
a=10
b=20
def multiply(a=5):
    mul=a*b
    print(mul)
multiply(a=3,b=10)
# the global value a=10, b=20
#while defining the function there is only one arguement
#while calling the function we mention two argumnts
#in this case it is not possible to call two arguements
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7824\592959633.py in <module>
#       4     mul=a*b
#       5     print(mul)
# ----> 6 multiply(a=3,b=10)
#       7 # the global value a=10, b=20
#       8 #while defining the function there is only one arguement
#
# TypeError: multiply() got an unexpected keyword argument 'b'

# %%
a=10
b=20
def multiply(a=5):
    mul=a*b
    print(mul)
multiply(a=3)
#the global value is a=10
#while defining the function a=5
#while calling the function a=3
#the function takes the latest value as a=3
# Out:
# 60

# %%
a=10
b=20
def multiply(a=3):

    mul=a*b
    print(mul)

multiply(a=2)
#the global value a=10
# while defining the function a=3
#while calling the function a=2
#it takes the latest value as a=2
# Out:
# 40

# %%
a=10
b=20
def multiply(a=3):
    a=5
    mul=a*b
    print(mul)
a=4
multiply(a=2)
#the global value a=10
#while the function is defining as a=3
#the value is chamged as a=4
#while calling the value a=2
#while running the function the value a=5
# it takes the latest value as input
# Out:
# 100

# %%
b=5
def multiply():

    mul=a*b
    print(mul)
a=5
multiply()
#the global value b=5,a=5
# the function is defing and calling with default values
# while running it take global values
# Out:
# 25
