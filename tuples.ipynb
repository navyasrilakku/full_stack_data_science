# %% [markdown]
# - Representations
#
# - type
#
# - len
#
# - max
#
# - min
#
# - sorted
#
# - reversed
#
# - in
#
# - for loop in
#
# - index
#
# - for loop index
#
# - mutable
#
# - concatenation
#
# - slicing
#
# - methods

# %% [markdown]
# **Representations**

# %% [markdown]
# - tuples represent with rounded braces

# %%
t1=(1,2,3,4)
t1
# Out:
# (1, 2, 3, 4)

# %%
type(t1)
# Out:
# tuple

# %%
t2=('A','B','C','D')
t2
# Out:
# ('A', 'B', 'C', 'D')

# %%
t3=(1,3,2,4,'A','B','C')
t3
# Out:
# (1, 3, 2, 4, 'A', 'B', 'C')

# %%
t4=(1,3,2,4,'A','B','C',True,False)
t4
# Out:
# (1, 3, 2, 4, 'A', 'B', 'C', True, False)

# %%
name='navya'
t5=(name)
t5
# Out:
# 'navya'

# %%
t6=[100,100,100]
t6
# Out:
# [100, 100, 100]

# %%
t7=(100,'Apple',('A',2))
t7
# Out:
# (100, 'Apple', ('A', 2))

# %%
t8=(100,'Apple',['A',2])
t8
# Out:
# (100, 'Apple', ['A', 2])

# %%
t9=[100,'Apple',('A',2)]
t9
# Out:
# [100, 'Apple', ('A', 2)]

# %% [markdown]
# - len
# - max
# - min
# - sorted
# - reversed

# %%
len(t3)
# Out:
# 7

# %%
len(t9)
# Out:
# 3

# %%
max(t2)
# Out:
# 'D'

# %%
max(t1)
# Out:
# 4

# %%
min(t2)
# Out:
# 'A'

# %%
min(t1)
# Out:
# 1

# %%
tu=(3,7,1,8)
k=sorted(tu)
k
# Out:
# [1, 3, 7, 8]

# %%
tu=(3,7,1,8)
k=sorted(tu)
k
# Out:
# [1, 3, 7, 8]

# %%
m=reversed(k)

# %%
for i in m:
    print(i,end=' ')
# Out:
# 8 7 3 1

# %%
tuple(reversed(k))
# Out:
# (8, 7, 3, 1)

# %%
t9=('ankita','chandana','madhura')
max(t9)
# Out:
# 'madhura'

# %%
tu4=(1,2,3,'Apple','Ball','Cat',True,False)

#-8  -7  -6    -5     -4    -3    -2    -1
#1    2   3   Apple  Ball  Cat   True   False
#0    1   2    3      4     5      6     7

# %%
tu4[3],tu4[-5]
# Out:
# ('Apple', 'Apple')

# %%
tu3=(1,(6,1))
tu3[1][0]
# Out:
# 6

# %%
tup1=('MH',
       ('Nagpur',('Orange',('likes',('king'),('shivaji',('Son',('shmbaji')))))
       ))
len(tup1)
# Out:
# 2

# %%
tup1[1][1][1][2][1][1]
# Out:
# 'shmbaji'

# %%
tup2=(1,2,3,'A','B','C',True,False)

#-8  -7   -6   -5     -4    -3    -2    -1
#1   2    3    'A'    'B'   'C'   True  False
#0   1    2     3      4     5     6     7
for i in range(len(tup2)):
    print(tup2[i],end=' ')
# Out:
# 1 2 3 A B C True False

# %%
tup5=[1,2,3,'A','B','C',True,False]
for i in range(len(tup5)):
    print(f"The postive index of {tup5[i]} is {i}")
# Out:
# The postive index of 1 is 0
# The postive index of 2 is 1
# The postive index of 3 is 2
# The postive index of A is 3
# The postive index of B is 4
# The postive index of C is 5
# The postive index of True is 6
# The postive index of False is 7

# %%
l=(1,2,3)
l[0]=100
l
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10472\4145510454.py in <module>
#       1 l=(1,2,3)
# ----> 2 l[0]=100
#       3 l
#
# TypeError: 'tuple' object does not support item assignment

# %%
dir(())
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
tup7=(1,4,7,3,7,9,3,9,7,5,4,4,9)
tup7.count(1)
# Out:
# 1

# %%
tup7.index(7)
# Out:
# 2

# %%
tup7[::-1]
# Out:
# (9, 4, 4, 5, 7, 9, 3, 9, 7, 3, 7, 4, 1)

# %%
tup7[5:9]
# Out:
# (9, 3, 9, 7)
