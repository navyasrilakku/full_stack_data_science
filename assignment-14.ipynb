# %%
ls1=[1,2,3,4]
for i in ls1:
    print(i, end=" ")
# Out:
# 1 2 3 4

# %%
ls1=[1,2,3,4]
for i in ls1:
    print(ls1[2], end=" ")
# Out:
# 3 3 3 3

# %%
ls1=[1,2,3,4]
ls1[0:4:2]
# Out:
# [1, 3]

# %%
ls1[0]=4

# %%
ls1=[1,2,4]
ls2=[3,5,6]
ls3=ls1+ls2
ls3
# Out:
# [1, 2, 4, 3, 5, 6]

# %%
ls1=[3,2,9,4]
for i in range(len(ls1)):
    print(f"{ls1[i]}  {i-len(ls1)}Negative---->{i} positive")
# Out:
# 3  -4Negative---->0 positive
# 2  -3Negative---->1 positive
# 9  -2Negative---->2 positive
# 4  -1Negative---->3 positive

# %%
ls1=[3,2,9,4]
for i in range(len(ls1)):
    print(f"{ls1[i]} ----->{i} positive")
# Out:
# 3 ----->0 positive
# 2 ----->1 positive
# 9 ----->2 positive
# 4 ----->3 positive

# %%
ls1=[3,2,9,4]
for i in range(len(ls1)):
    print(f"{ls1[i]} ----->{i-len(ls1)} negative")
# Out:
# 3 ----->-4 negative
# 2 ----->-3 negative
# 9 ----->-2 negative
# 4 ----->-1 negative
