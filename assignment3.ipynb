# %%
# Ramesh’s basic salary is input through the keyboard. His deamess allowance is 40% of basic salary, and
# house rent allowance is 20% of basic salary. Write a program to calculate his gross salary.
basic_salary=eval(input("ente salary: "))
deamess_allowance=(40/100)*basic_salary
house_rent=(20/100)*basic_salary
gross_salary=basic_salary+deamess_allowance+house_rent
print(gross_salary)
# Out:
# ente salary: 100000
# 160000.0

# %%
#The distance between two cities (in km.) is input through the keyboard. Write a program to convert and
#print this distance in meters, feet, inches and centimeters.
distance=eval(input("enter the distance b/w two cities in kms: "))
meters=distance*1000
centimeters=distance*100000
feet= distance*3280.8399
inches=distance*39370.0787
print("meters: ",meters)
print("centimeters: ", centimeters)
print("feet: ", feet)
print("Inchs: ", inches)
# Out:
# enter the distance b/w two cities in kms: 5
# meters:  5000
# centimeters:  500000
# feet:  16404.1995
# Inchs:  196850.3935

# %%
#If the marks obtained by a student in five different subjects are input through the keyboard, find out 
#the aggregate marks and percentage marks obtained by the student. Assume that the maximum marks that
#can be obtained by a student in each subject is 100.
s1=eval(input("enter s1: "))
s2=eval(input("enter s2: "))
s3=eval(input("enter s3: "))
s4=eval(input("enter s4: "))
s5=eval(input("enter s5: "))
total=s1+s2+s3+s4+s5
percentage=(total/500)*100
print("total: ",total)
print("percentage: ", percentage)
# Out:
# enter s1: 90
# enter s2: 95
# enter s3: 94
# enter s4: 96
# enter s5: 98
# total:  473
# percentage:  94.6

# %%
#Temperature of a city in Fahrenheit degrees is input through the keyboard. Write a program to convert this
#temperature into Centigrade degrees.
fahrenheit= eval(input("enter temp in fahrenheit: "))
centigrade_degree= (fahrenheit-32)/1.8
print("centigrade_degree: ", centigrade_degree)
# Out:
# enter temp in fahrenheit: 50
# centigrade_degree:  10.0

# %%
#The length & breadth of a rectangle and radius of a circle are input through the keyboard. 
#Write a program to calculate the area & perimeter of the rectangle, and the area & circumference of the circle.
leng=eval(input("enter length: "))
bredth=eval(input("enter bredth: "))
rad=eval(input("enter radius: "))
area_r=(leng*leng)+(bredth*bredth)
area_c=3.14*rad*rad
circum_c=2*3.4*rad
perimeter_r= 2*(leng+bredth)
print("area of circle: ", area_c)
print("area of rectangle: ", area_r)
print("circumference of circle: ", circum_c)
print("perimeter of rectangle: ", perimeter_r)
# Out:
# enter length: 5
# enter bredth: 4
# enter radius: 3
# area of circle:  28.259999999999998
# area of rectangle:  41
# circumference of circle:  20.4
# perimeter of rectangle:  18

# %%
#Two numbers are input through the keyboard into two locations C and D. Write a program to interchangethe contents of C and D.
a= eval(input("enter a: "))
b=eval(input("enter b: "))
c=b
b=a
a=c
print("after changes")
print("a:",a)
print("b:",b)
# Out:
# enter a: 7
# enter b: 5
# after changes
# a: 5
# b: 7

# %%
#If a five-digit number is input through the keyboard, write a program to reverse the number.
n = eval(input("enter a number: "))
rev = 0
  
while(n > 0): 
    a = n % 10
    rev = rev * 10 + a 
    n = n // 10
  
print(rev)
# Out:
# enter a number: 27012003
# 30021072

# %%
#If a four-digit number is input through the keyboard, write a program to obtain the sum of the first and last digit of this number.
n=int(input("Enter the four Digits Number :"))
sum1=0
a=n//1000
sum1=sum1+a
a=n%10
sum1=sum1+a
print(sum1)
# Out:
# Enter the four Digits Number :2701
# 3

# %%
#In a town, the percentage of men is 52. The percentage of total literacy is 48. If total percentage of literate
#men is 35 of the total population, write a program to find the total number of illiterate men and women if
#the population of the town is 80,000.

# %%
#A cashier has currency notes of denominations 10, 50 and 100. If the amount to be withdrawn is input
#through the keyboard in hundreds, find the total number of currency notes of each denomination the
#cashier will have to give to the withdrawer.
