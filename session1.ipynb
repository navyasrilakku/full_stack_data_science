# %%
a=10
b=20
c=a+b
c
# Out:
# 30

# %% [markdown]
# - I am navya sri

# %% [markdown]
# # python
# ## python
# ### Python

# %% [markdown]
# - Today I learn how to open jupter notebook
# - I created a folder
# - From tomorrow i will learn
# - I Understood about kernal
# - Bcoz python kernal will run step by step
# - This is called markdown
# - I understood kernal
# - esc+m is shortcut for code mode to markdown
# - esc+y is shortcut for escape mode to code

# %% [markdown]
# <img id="dimg_227" src="data:image/png;base64,..." class="YQ4gaf" height="168" style="object-position:0% 38%" width="300" alt="Jupyter Notebooks: A Beginner's Guide ..." data-csiid="20" data-atf="1">

# %% [markdown]
# # variable
# variables are used to store the values can be changed

# %%
n=100 # value 100 stored in a variable name n
n #shift+enter
# Out:
# 100

# %%
n=200 # value 100 stored in a variable name n
n #shift+enter
# Out:
# 200

# %% [markdown]
# ** Note**
# - python is a step by step process
# - it takes the last values
# - in above code we use same variable
# - but values changed for variable is changed
# - 1 st value 100
# - 2nd value 200
# - the answer is 200

# %%
NUMBER=300
NUMBER
# Out:
# 300

# %%
n, NUMBER
# Out:
# (200, 300)

# %%
num123=400
num123
# Out:
# 400

# %%
123num = 400
123num
# Out:
#   File "C:\Users\My world\AppData\Local\Temp\ipykernel_9556\473538983.py", line 1
#     123num = 400
#        ^
# SyntaxError: invalid syntax

# %%
num%er=600
num%er
# Out:
#   File "C:\Users\My world\AppData\Local\Temp\ipykernel_9556\2211805861.py", line 1
#     num%er=600
#     ^
# SyntaxError: cannot assign to operator

# %%
num one=200
num one
# Out:
#   File "C:\Users\My world\AppData\Local\Temp\ipykernel_9556\4126917059.py", line 1
#     num one=200
#         ^
# SyntaxError: invalid syntax

# %%
num_one=400
num_one
# Out:
# 400

# %%
_=100
_
# Out:
# 100

# %%
n1,n2=100
n1,n2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9556\2659360926.py in <module>
# ----> 1 n1,n2=100
#       2 n1,n2
#
# TypeError: cannot unpack non-iterable int object

# %%
n1=100,200
n1
# Out:
# (100, 200)

# %%
n3=400
n4=800
print(n3)
print(n4)
# Out:
# 400
# 800

# %% [markdown]
# - python variables are case sensitive
# - variables can be declare as capital letters
# - variables can be declare as small ltters
# - variables can not start with numbers
# - numbers can be suffix of letters
# - variables can not have special characters
# - only underscore is possibe
# - variables can not have space in between
# - keywords  cannot be allowed
# - sigle value cannot assigned to a two variables or more
# - single variable can have multiple values
