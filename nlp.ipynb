# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
dir(nltk)
# Out:
# ['ARLSTem',
#  'ARLSTem2',
#  'AbstractLazySequence',
#  'AffixTagger',
#  'AlignedSent',
#  'Alignment',
#  'AnnotationTask',
#  'ApplicationExpression',
#  'Assignment',
#  'BigramAssocMeasures',
#  'BigramCollocationFinder',
#  'BigramTagger',
#  'BinaryMaxentFeatureEncoding',
#  'BlanklineTokenizer',
#  'BllipParser',
#  'BottomUpChartParser',
#  'BottomUpLeftCornerChartParser',
#  'BottomUpProbabilisticChartParser',
#  'Boxer',
#  'BrillTagger',
#  'BrillTaggerTrainer',
#  'CFG',
#  'CRFTagger',
#  'CfgReadingCommand',
#  'ChartParser',
#  'ChunkParserI',
#  'ChunkScore',
#  'Cistem',
#  'ClassifierBasedPOSTagger',
#  'ClassifierBasedTagger',
#  'ClassifierI',
#  'ConcordanceIndex',
#  'ConditionalExponentialClassifier',
#  'ConditionalFreqDist',
#  'ConditionalProbDist',
#  'ConditionalProbDistI',
#  'ConfusionMatrix',
#  'ContextIndex',
#  'ContextTagger',
#  'ContingencyMeasures',
#  'CoreNLPDependencyParser',
#  'CoreNLPParser',
#  'Counter',
#  'CrossValidationProbDist',
# ...

# %%
# if we want to do separate package  we need to do below thing
# if you already done don't run it again
# import nltk
# nltk.download('punkt')

# %%
filename='metamorphosis clean.txt'
file=open(filename,'rt')
text=file.read()

# %%
text
# Out:
# 'One morning, when Gregor Samsa woke from troubled dreams, he found\nhimself transformed in his bed into a horrible vermin.  He lay on\nhis armour-like back, and if he lifted his head a little he could\nsee his brown belly, slightly domed and divided by arches into stiff\nsections.  The bedding was hardly able to cover it and seemed ready\nto slide off any moment.  His many legs, pitifully thin compared\nwith the size of the rest of him, waved about helplessly as he\nlooked.\n\n"What\'s happened to me?" he thought.  It wasn\'t a dream.  His room,\na proper human room although a little too small, lay peacefully\nbetween its four familiar walls.  A collection of textile samples\nlay spread out on the table - Samsa was a travelling salesman - and\nabove it there hung a picture that he had recently cut out of an\nillustrated magazine and housed in a nice, gilded frame.  It showed\na lady fitted out with a fur hat and fur boa who sat upright,\nraising a heavy fur muff that covered the who
# ...

# %%
words=text.split()

# %%
len(words)
# Out:
# 22086

# %%
words[:20]
# Out:
# ['One',
#  'morning,',
#  'when',
#  'Gregor',
#  'Samsa',
#  'woke',
#  'from',
#  'troubled',
#  'dreams,',
#  'he',
#  'found',
#  'himself',
#  'transformed',
#  'in',
#  'his',
#  'bed',
#  'into',
#  'a',
#  'horrible',
#  'vermin.']

# %% [markdown]
# **tokenization**

# %% [markdown]
# **punctuations**

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
dir(string)
# Out:
# ['Formatter',
#  'Template',
#  '_ChainMap',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_re',
#  '_sentinel_dict',
#  '_string',
#  'ascii_letters',
#  'ascii_lowercase',
#  'ascii_uppercase',
#  'capwords',
#  'digits',
#  'hexdigits',
#  'octdigits',
#  'printable',
#  'punctuation',
#  'whitespace']

# %%
string.ascii_letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.digits
# Out:
# '0123456789'

# %%
string.whitespace
# Out:
# ' \t\n\r\x0b\x0c'

# %%
string.capwords
# Out:
# <function string.capwords(s, sep=None)>

# %%
string.hexdigits
# Out:
# '0123456789abcdefABCDEF'

# %%
string.octdigits
# Out:
# '01234567'

# %%
string.printable
# Out:
# '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c'

# %%
len(string.printable)
# Out:
# 100

# %% [markdown]
# **regex**
# - to remove the punctuations we use regex package

# %%
import re

# %%
text='The indians are very Smart'
text.count('ar')# normal string
# Out:
# 2

# %%
text='The indians are very Smart'
re.findall('ar',text)# normal string
# Out:
# ['ar', 'ar']

# %%
dir(re)
# Out:
# ['A',
#  'ASCII',
#  'DEBUG',
#  'DOTALL',
#  'I',
#  'IGNORECASE',
#  'L',
#  'LOCALE',
#  'M',
#  'MULTILINE',
#  'Match',
#  'Pattern',
#  'RegexFlag',
#  'S',
#  'Scanner',
#  'T',
#  'TEMPLATE',
#  'U',
#  'UNICODE',
#  'VERBOSE',
#  'X',
#  '_MAXCACHE',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__version__',
#  '_cache',
#  '_compile',
#  '_compile_repl',
#  '_expand',
#  '_locale',
#  '_pickle',
#  '_special_chars_map',
#  '_subx',
#  'compile',
#  'copyreg',
#  'enum',
#  'error',
#  'escape',
#  'findall',
#  'finditer',
#  'fullmatch',
#  'functools',
#  'match',
#  'purge',
#  'search',
#  'split',
#  'sre_compile',
#  'sre_parse',
#  'sub',
#  'subn',
#  'template']

# %%
text='The indians are very Smart'
string1='indians'# normal string
string1 in text
# Out:
# True

# %%
text='The indians are very Smart'
re.search('indians',text)# normal string
# Out:
# <re.Match object; span=(4, 11), match='indians'>

# %%
re.search('indians',text).group()
# Out:
# 'indians'

# %% [markdown]
# **remove punctuations**

# %%
text1="hi jayanth what's up"

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
re.escape(string.punctuation)
# Out:
# '!"\\#\\$%\\&\'\\(\\)\\*\\+,\\-\\./:;<=>\\?@\\[\\\\\\]\\^_`\\{\\|\\}\\~'

# %% [markdown]
# **re.compile**

# %%
pattern=re.compile('\d+')
text="there are 12 apples and 13 oranges"
pattern.findall(text)
# Out:
# ['12', '13']

# %%
text1="hai jayanth what's up"

# %%
pattern=re.compile('(\d{3})-(\d{3})-(\d{4})')
text="mobile number is 970-196-2333"
pattern.findall(text)
# Out:
# [('970', '196', '2333')]

# %%
pattern=re.compile(r'\b\w{4}\b')
text="hello how are you good"
pattern.findall(text)
# Out:
# ['good']

# %%
re_punct=re.compile('[%s]'%re.escape(string.punctuation))
re_punct
# Out:
# re.compile(r'[!"\#\$%\&\'\(\)\*\+,\-\./:;<=>\?@\[\\\]\^_`\{\|\}\~]',
# re.UNICODE)

# %%
for w in words:
    print("with:",w)
    print(re_punct.sub('',w))
# Out:
# with: One
# One
# with: morning,
# morning
# with: when
# when
# with: Gregor
# Gregor
# with: Samsa
# Samsa
# with: woke
# woke
# with: from
# from
# with: troubled
# troubled
# with: dreams,
# dreams
# with: he
# he
# with: found
# found
# with: himself
# himself
# with: transformed
# transformed
# with: in
# in
# with: his
# his
# with: bed
# bed
# with: into
# into
# with: a
# a
# with: horrible
# horrible
# with: vermin.
# vermin
# with: He
# He
# with: lay
# lay
# with: on
# on
# with: his
# his
# with: armour-like
# armourlike
# with: back,
# back
# with: and
# and
# with: if
# if
# with: he
# he
# with: lifted
# lifted
# with: his
# his
# with: head
# head
# with: a
# a
# with: little
# little
# with: he
# he
# with: could
# could
# with: see
# see
# with: his
# his
# with: brown
# brown
# with: belly,
# belly
# with: slightly
# slightly
# with: domed
# domed
# with: and
# and
# with: divided
# divided
# with: by
# by
# with: arches
# arches
# with: into
# into
# with: stiff
# ...

# %%
text1="hai jayath what's up"
words1=text1.split()
for w in words1:
    print("with:",w)
    print(re_punct.sub('',w))
# Out:
# with: hai
# hai
# with: jayath
# jayath
# with: what's
# whats
# with: up
# up

# %%
import string,re
re_punct=re.compile('[%s]'%re.escape(string.punctuation))
w=[re_punct.sub('',w) for w in words]
w
# Out:
# ['One',
#  'morning',
#  'when',
#  'Gregor',
#  'Samsa',
#  'woke',
#  'from',
#  'troubled',
#  'dreams',
#  'he',
#  'found',
#  'himself',
#  'transformed',
#  'in',
#  'his',
#  'bed',
#  'into',
#  'a',
#  'horrible',
#  'vermin',
#  'He',
#  'lay',
#  'on',
#  'his',
#  'armourlike',
#  'back',
#  'and',
#  'if',
#  'he',
#  'lifted',
#  'his',
#  'head',
#  'a',
#  'little',
#  'he',
#  'could',
#  'see',
#  'his',
#  'brown',
#  'belly',
#  'slightly',
#  'domed',
#  'and',
#  'divided',
#  'by',
#  'arches',
#  'into',
#  'stiff',
#  'sections',
#  'The',
#  'bedding',
#  'was',
#  'hardly',
#  'able',
#  'to',
#  'cover',
#  'it',
#  'and',
#  'seemed',
#  'ready',
#  'to',
#  'slide',
#  'off',
#  'any',
#  'moment',
#  'His',
#  'many',
#  'legs',
#  'pitifully',
#  'thin',
#  'compared',
#  'with',
#  'the',
#  'size',
#  'of',
#  'the',
#  'rest',
#  'of',
#  'him',
#  'waved',
#  'about',
#  'helplessly',
#  'as',
#  'he',
#  'looked',
#  'Whats',
#  'happened',
# ...

# %%
import re
text1="hai jay$$$anth what's u&p"
words=text1.split()
print(words)
re_punct=re.compile('[%s]'%re.escape(string.punctuation))
w=[re_punct.sub('',w) for w in words]
print(w)
# Out:
# ['hai', 'jay$$$anth', "what's", 'u&p']
# ['hai', 'jayanth', 'whats', 'up']

# %%
import re
text1="hai kow$$$shik what's u&p. hello de###epak , sour@@@@av"
words=text1.split()
print(words)
re_punct= re.compile('[%s]'%re.escape(string.punctuation))
w=[re_punct.sub('',w) for w in words]
print(w)
# Out:
# ['hai', 'kow$$$shik', "what's", 'u&p.', 'hello', 'de###epak', ',', 'sour@@@@av']
# ['hai', 'kowshik', 'whats', 'up', 'hello', 'deepak', '', 'sourav']

# %%
def re_exp(text):
    print('originaltext:',text)
    words=text.split()
    print(words)
    re_punct=re.compile('[%s]'%re.escape(string.punctuation))
    w=[re_punct.sub('',w) for w in words]
    sent=''.join(w)
    print(w)
    print("preprocessed text:", sent)
re_exp("hello harsh***")
# Out:
# originaltext: hello harsh***
# ['hello', 'harsh***']
# ['hello', 'harsh']
# preprocessed text: helloharsh

# %% [markdown]
# **Normalization**

# %% [markdown]
# - convert to lower case

# %%
def text_cleaning(text1):
    words=text1.split()
    re_punct=re.compile('[%s]'%re.escape(string.punctuation))
    w=[re_punct.sub('',w) for w in words]
    w=[i.lower() for i in w]
    return (w)
text1="haii navya sri how are you?"
text_cleaning(text1)
# Out:
# ['haii', 'navya', 'sri', 'how', 'are', 'you']

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
words=word_tokenize(text)
words[:20]
# Out:
# ['hello', 'how', 'are', 'you', 'good']

# %%
filename='metamorphosis clean.txt'
file=open(filename,'rt')
text=file.read()

# %%
tokens=word_tokenize(text)
print(tokens[:4])
words=[word for word in tokens if word.isalnum()]
words[:10]
# Out:
# ['One', 'morning', ',', 'when']
# ['One',
#  'morning',
#  'when',
#  'Gregor',
#  'Samsa',
#  'woke',
#  'from',
#  'troubled',
#  'dreams',
#  'he']

# %%
re_punct=re.compile('[%s]'%re.escape(string.punctuation))
w=[re_punct.sub('',w) for w in tokens]
print(w[:4])
# Out:
# ['One', 'morning', '', 'when']

# %%
tokens=[word for word in w if word.isalnum()]
print(tokens[:4])
# Out:
# ['One', 'morning', 'when', 'Gregor']

# %%
dir(stopwords)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_citation',
#  '_encoding',
#  '_fileids',
#  '_get_root',
#  '_license',
#  '_readme',
#  '_root',
#  '_tagset',
#  '_unload',
#  'abspath',
#  'abspaths',
#  'citation',
#  'encoding',
#  'ensure_loaded',
#  'fileids',
#  'license',
#  'open',
#  'raw',
#  'readme',
#  'root',
#  'words']

# %%
from nltk.corpus import stopwords
eng_stop_words=stopwords.words('english')
print(eng_stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
stopwords.fileids()
# Out:
# ['arabic',
#  'azerbaijani',
#  'basque',
#  'bengali',
#  'catalan',
#  'chinese',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'greek',
#  'hebrew',
#  'hinglish',
#  'hungarian',
#  'indonesian',
#  'italian',
#  'kazakh',
#  'nepali',
#  'norwegian',
#  'portuguese',
#  'romanian',
#  'russian',
#  'slovene',
#  'spanish',
#  'swedish',
#  'tajik',
#  'turkish']

# %%
stop_words1=stopwords.words('english')
words=[w for w in tokens if not w in stop_words1]

# %%
words
# Out:
# ['One',
#  'morning',
#  'Gregor',
#  'Samsa',
#  'woke',
#  'troubled',
#  'dreams',
#  'found',
#  'transformed',
#  'bed',
#  'horrible',
#  'vermin',
#  'He',
#  'lay',
#  'armourlike',
#  'back',
#  'lifted',
#  'head',
#  'little',
#  'could',
#  'see',
#  'brown',
#  'belly',
#  'slightly',
#  'domed',
#  'divided',
#  'arches',
#  'stiff',
#  'sections',
#  'The',
#  'bedding',
#  'hardly',
#  'able',
#  'cover',
#  'seemed',
#  'ready',
#  'slide',
#  'moment',
#  'His',
#  'many',
#  'legs',
#  'pitifully',
#  'thin',
#  'compared',
#  'size',
#  'rest',
#  'waved',
#  'helplessly',
#  'looked',
#  'What',
#  'happened',
#  'thought',
#  'It',
#  'nt',
#  'dream',
#  'His',
#  'room',
#  'proper',
#  'human',
#  'room',
#  'although',
#  'little',
#  'small',
#  'lay',
#  'peacefully',
#  'four',
#  'familiar',
#  'walls',
#  'A',
#  'collection',
#  'textile',
#  'samples',
#  'lay',
#  'spread',
#  'table',
#  'Samsa',
#  'travelling',
#  'salesman',
#  'hung',
# ...

# %% [markdown]
# **summarize**
# - load the raw text
# - split into tokens
# - convert into lower case
# - remove punctuations from each case
# - filter out each token which are not alphabet
# - filter out tokens that are stop words

# %% [markdown]
# **stemming**
#
# ***stem words***

# %% [markdown]
# - reducing of ach word to root or base
# - fishing, fished, fisher ===>fish
# - In NLP making a vocabulary , a dictionary
# - based on your use case will create our own vocabulary
# - we create our own dictionary
# - to do the stemming   in NLTK ====> PorterStemmer

# %%
from nltk.stem import PorterStemmer
ps=PorterStemmer()
ps.stem("pythoned")
# Out:
# 'python'

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
w1=["python","pythoner","pythonly","pythoned"]
ps1=PorterStemmer()
w2=[ps1.stem(w) for w in w1]
w2
# Out:
# ['python', 'python', 'pythonli', 'python']

# %%
text9="all pythoners should be pythoned will with python, every one atleast pythones veery poorly with python"
w2=[ps.stem(w) for w in text9]
w2
# Out:
# ['a',
#  'l',
#  'l',
#  ' ',
#  'p',
#  'y',
#  't',
#  'h',
#  'o',
#  'n',
#  'e',
#  'r',
#  's',
#  ' ',
#  's',
#  'h',
#  'o',
#  'u',
#  'l',
#  'd',
#  ' ',
#  'b',
#  'e',
#  ' ',
#  'p',
#  'y',
#  't',
#  'h',
#  'o',
#  'n',
#  'e',
#  'd',
#  ' ',
#  'w',
#  'i',
#  'l',
#  'l',
#  ' ',
#  'w',
#  'i',
#  't',
#  'h',
#  ' ',
#  'p',
#  'y',
#  't',
#  'h',
#  'o',
#  'n',
#  ',',
#  ' ',
#  'e',
#  'v',
#  'e',
#  'r',
#  'y',
#  ' ',
#  'o',
#  'n',
#  'e',
#  ' ',
#  'a',
#  't',
#  'l',
#  'e',
#  'a',
#  's',
#  't',
#  ' ',
#  'p',
#  'y',
#  't',
#  'h',
#  'o',
#  'n',
#  'e',
#  's',
#  ' ',
#  'v',
#  'e',
#  'e',
#  'r',
#  'y',
#  ' ',
#  'p',
#  'o',
#  'o',
#  'r',
#  'l',
#  'y',
#  ' ',
#  'w',
#  'i',
#  't',
#  'h',
#  ' ',
#  'p',
#  'y',
#  't',
#  'h',
#  'o',
#  'n']

# %%
from nltk import pos_tag

# %%
text="he received best actor award"
pos_tag(word_tokenize(text))
# Out:
# [('he', 'PRP'),
#  ('received', 'VBD'),
#  ('best', 'JJS'),
#  ('actor', 'NN'),
#  ('award', 'NN')]

# %%
from nltk import word_tokenize, sent_tokenize

# %% [markdown]
# **lemmatisation**

# %% [markdown]
# - lemmatisation is similar to stemming, as it produces a normalised version of the input word
# - the output is lemma i.e. Proper word
# - the input word is lemmatised according to its part-of-speech(pos)tag

# %%
from nltk.stem import WordNetLemmatizer
s=WordNetLemmatizer()
print(s.lemmatize('having',pos='v'))
print(s.lemmatize('have',pos='v'))
print(s.lemmatize('had',pos='v'))
print(s.lemmatize('fishing',pos='v'))
print(s.lemmatize('fisher',pos='v'))
print(s.lemmatize('fish',pos='v'))
print(s.lemmatize('fishes',pos='v'))
print(s.lemmatize('fished',pos='v'))
# Out:
# have
# have
# have
# fish
# fisher
# fish
# fish
# fish

# %% [markdown]
# **WordNet**

# %%
from nltk.corpus import wordnet

# %%
syns1=wordnet.synsets('good')
syns1
# Out:
# [Synset('good.n.01'),
#  Synset('good.n.02'),
#  Synset('good.n.03'),
#  Synset('commodity.n.01'),
#  Synset('good.a.01'),
#  Synset('full.s.06'),
#  Synset('good.a.03'),
#  Synset('estimable.s.02'),
#  Synset('beneficial.s.01'),
#  Synset('good.s.06'),
#  Synset('good.s.07'),
#  Synset('adept.s.01'),
#  Synset('good.s.09'),
#  Synset('dear.s.02'),
#  Synset('dependable.s.04'),
#  Synset('good.s.12'),
#  Synset('good.s.13'),
#  Synset('effective.s.04'),
#  Synset('good.s.15'),
#  Synset('good.s.16'),
#  Synset('good.s.17'),
#  Synset('good.s.18'),
#  Synset('good.s.19'),
#  Synset('good.s.20'),
#  Synset('good.s.21'),
#  Synset('well.r.01'),
#  Synset('thoroughly.r.02')]

# %%
import nltk
nltk.help.upnet_tagset()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9932\2312847772.py in <module>
#       1 import nltk
# ----> 2 nltk.help.upnet_tagset()
#
# AttributeError: module 'nltk.help' has no attribute 'upnet_tagset'

# %%
word1=wordnet.synset('good.n.01')
print(word1.definition())
print(word1.examples())
# Out:
# benefit
# ['for your own good', "what's the good of worrying?"]

# %% [markdown]
# - re packages
# - tokenization(punkt)
# - normalization
# - stopwords(corpus)
# - stemming(PorterStemmer)
# - lemmatization(stem)
# - pos(pos tag)
# -

# %%
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      -------------------------------------- 300.4/300.4 kB 2.1 MB/s eta 0:00:00
# ...
#   WARNING: The script wordcloud_cli.exe is installed in 'C:\Users\My world\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip --no-warn-script-location
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Usage:
#   C:\ProgramData\Anaconda3\python.exe -m pip <command> [options]
#
# no such option: --no-warn-script-location
