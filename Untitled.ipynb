# %%
import cv2

# %%
img= 'invoice-sample.jpg'

# %%
cv2.imread(img)
# Out:
# array([[[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        ...,
#
#        [[240, 240, 240],
#         [240, 240, 240],
#         [240, 240, 240],
#         ...,
#         [240, 240, 240],
#         [240, 240, 240],
#         [240, 240, 240]],
#
#        [[240, 240, 240],
#         [240, 240, 240],
#         [240, 240, 240],
#         ...,
#         [240, 240, 240],
#         [240, 240, 240],
#         [240, 240, 240]],
#
#        [[240, 240, 240],
#         [240, 240, 240],
#         [240, 240, 240],
# ...

# %%
import matplotlib.pyplot as plt

# %%
print(cv2.__version__)
# Out:
# 4.9.0

# %%
pip list -o
# Out:
# Package                       Version              Latest      Type
# ----------------------------- -------------------- ----------- -----
# absl-py                       2.0.0                2.1.0       wheel
# alabaster                     0.7.12               0.7.16      wheel
# annotated-types               0.5.0                0.7.0       wheel
# anyio                         3.5.0                4.7.0       wheel
# argon2-cffi                   21.3.0               23.1.0      wheel
# arrow                         1.2.2                1.3.0       wheel
# astroid                       2.11.7               3.3.8       wheel
# astropy                       5.1                  6.0.1       wheel
# atomicwrites                  1.4.0                1.4.1       sdist
# attrs                         21.4.0               24.3.0      wheel
# Automat                       20.2.0               24.8.1      wheel
# autopep8                      1.6.0                2.3.1       wheel
# ...

# %%
# !pip install --upgrade opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      -------------------------------------- 38.8/38.8 MB 977.9 kB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.9.0.80
#     Uninstalling opencv-python-4.9.0.80:
#       Successfully uninstalled opencv-python-4.9.0.80
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\My world\\AppData\\Roaming\\Python\\Python39\\site-packages\\~v2\\cv2.pyd'
# Check the permissions.

# %%
# !pip install --upgrade opencv-python-headless
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 38.8/38.8 MB 1.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
# ...
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\my world\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\my world\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\my world\appdata\roaming\python\python39\site-packages)
#     WARNING: Ignoring invalid distribution -pencv-python (c:\users\my world\appdata\roaming\python\python39\site-packages)
# ...
