# %%
str1='Navya2701'
str1.isalnum()
# Out:
# True

# %%
str1='Navya'
str1.isalpha()
# Out:
# True

# %%
str1='Navya'
str1.isascii()
# Out:
# True

# %%
str1='01000'
str1.isdecimal()
# Out:
# True

# %%
str1="2345678"
str1.isdigit()
# Out:
# True

# %%
str1="----"
str1.isidentifier()
# Out:
# False

# %%
str1='navya'
str1.islower()
# Out:
# True

# %%
str1='345678'
str1.isnumeric()
# Out:
# True

# %%
str1="56t7y7uik"
str1.isprintable()
# Out:
# True

# %%
str1=" "
str1.isspace()
# Out:
# True

# %%
str1="ERTYU"
str1.istitle()
# Out:
# False

# %%
str1="WERTY"
str1.isupper()
# Out:
# True
