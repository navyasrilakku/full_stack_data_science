# %%
string = "         Hello, World!            "
print(string.strip())
# Out:
# Hello, World!

# %%
string = "Hello, World!"
print(string.startswith("Hello"))
# Out:
# True

# %%
string = "Hello, World!"
print(string.startswith("Goodbye"))
# Out:
# False

# %%
string = "Hello, World!"
print(string.endswith("World!"))
# Out:
# True

# %%
string = "Hello, World!"
print(string.endswith("Universe"))
# Out:
# False

# %%
string = "   Hello, World!   "
print(string.lstrip())
# Out:
# Hello, World!

# %%
string = "   Hello, World!   "
print(string.rstrip())
# Out:
#    Hello, World!
