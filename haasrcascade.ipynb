# %%
import cv2
img=cv2.imread('photomini.jpg', cv2.COLOR_BGR2GRAY)
img
# Out:
# array([[[241, 223, 206],
#         [241, 223, 206],
#         [242, 224, 207],
#         ...,
#         [242, 226, 209],
#         [242, 226, 209],
#         [242, 226, 209]],
#
#        [[241, 223, 206],
#         [241, 223, 206],
#         [242, 224, 207],
#         ...,
#         [242, 226, 209],
#         [242, 226, 209],
#         [242, 226, 209]],
#
#        [[242, 224, 207],
#         [242, 224, 207],
#         [243, 225, 208],
#         ...,
#         [241, 225, 208],
#         [241, 225, 208],
#         [241, 225, 208]],
#
#        ...,
#
#        [[186, 186, 180],
#         [193, 193, 187],
#         [198, 198, 192],
#         ...,
#         [246, 229, 210],
#         [246, 229, 210],
#         [246, 229, 210]],
#
#        [[185, 185, 179],
#         [188, 188, 182],
#         [190, 190, 184],
#         ...,
#         [246, 229, 210],
#         [246, 229, 210],
#         [246, 229, 210]],
#
#        [[187, 187, 181],
#         [185, 185, 179],
#         [185, 185, 179],
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
mh=cv2.line(img,(0,200),(400,311),(255,0,0),5)

# %%
plt.imshow(mh)

# %%
mg=cv2.rectangle(mh,(350,350),(500,250),(0,255,0),3)

# %%
plt.imshow(mg)

# %%
k=cv2.circle(mg,(425,300),40,(0,0,255),-1)

# %%
plt.imshow(k)

# %%
import pytesseract
import cv2
pytesseract.pytesseract.tesseract_cmd=r'C:\Program Files\Tesseract-OCR\tesseract.exe'
numcasc=cv2.CascadeClassifier('haarcascade_russian_plate_number.xml')

dir(numcasc)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'convert',
#  'detectMultiScale',
#  'detectMultiScale2',
#  'detectMultiScale3',
#  'empty',
#  'getFeatureType',
#  'getOriginalWindowSize',
#  'isOldFormatCascade',
#  'load',
#  'read']

# %%
img = cv2.imread('r.jpeg',cv2.COLOR_BGR2GRAY)

img
# Out:
# array([[[ 27,  26,  28],
#         [ 26,  25,  27],
#         [ 26,  25,  27],
#         ...,
#         [121, 116, 115],
#         [120, 115, 114],
#         [120, 115, 114]],
#
#        [[ 32,  31,  33],
#         [ 32,  31,  33],
#         [ 31,  30,  32],
#         ...,
#         [121, 116, 115],
#         [120, 115, 114],
#         [120, 115, 114]],
#
#        [[ 43,  42,  44],
#         [ 43,  42,  44],
#         [ 41,  40,  42],
#         ...,
#         [120, 115, 114],
#         [120, 115, 114],
#         [119, 114, 113]],
#
#        ...,
#
#        [[  0,   0,   0],
#         [  1,   1,   1],
#         [  2,   2,   2],
#         ...,
#         [ 68,  71,  75],
#         [ 68,  71,  75],
#         [ 67,  70,  74]],
#
#        [[  0,   0,   0],
#         [  1,   1,   1],
#         [  2,   2,   2],
#         ...,
#         [ 67,  70,  74],
#         [ 68,  71,  75],
#         [ 68,  71,  75]],
#
#        [[  0,   0,   0],
#         [  2,   2,   2],
#         [  2,   2,   2],
# ...

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
img.shape
# Out:
# (683, 1024, 3)

# %%
start_window=(5,5)
end_window=(200,200)
color=(0,0,255)
thickness=5
rec_img=cv2.rectangle(img, start_window, end_window, color, thickness)
numpl=numcasc.detectMultiScale(img,1.1,6)

print(numpl)
for (x,y,w,h) in numpl:
    print(x,y)
    print(w,h)
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),3)
cv2.imshow("image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ()

# %%
h, w, c = img.shape
boxes = pytesseract.image_to_boxes(img)
for b in boxes.splitlines():
    b = b.split(' ')
    img = cv2.rectangle(img,
                        (int(b[1]), h - int(b[2])), (int(b[3]), h - int(b[4])),
                        (0, 255, 0),
                        1)

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import pytesseract
pytesseract.pytesseract.tesseract_cmd=r'C:\Program Files\Tesseract-OCR\tesseract.exe'
numcasc=cv2.CascadeClassifier('haarcascade_russian_plate_number.xml')
img = cv2.imread('r.jpeg',cv2.COLOR_BGR2GRAY)
im_path=cv2.imread(img)
if image is None:
    print("Error")
else:
    gray=cv2.cvtColor(im_path, cv2.COLOR_BGR2GRAY)
    plates=numcascdetectMultiScale(gray, scaleFactor 3.1, mintwighborsa, sinsizes (30, 30))
    for (x, y, w, h) in plates: cv2.rectangle(image, (x,
    y), (xw, yh), (0, 255, 0), 2)
    rol graylylyh, xca text pytesseract image
    to_string(rol, contige pse 8)
    print("Detected Number Plate Texti, test.strip())
cv2.imshow("Number Plate Detection", inage)
cv2.waitKey(0)
cv2.destroyAllWindows()
