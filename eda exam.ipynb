# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tdf=pd.read_csv('Titanic Dataset.csv')
tdf
# Out:
#         sex   age  sibsp  parch     fare embarked   class    who  alone  \
# 0      male  22.0      1      0   7.2500        S   Third    man  False
# 1    female  38.0      1      0  71.2833        C   First  woman  False
# 2    female  26.0      0      0   7.9250        S   Third  woman   True
# 3    female  35.0      1      0  53.1000        S   First  woman  False
# 4      male  35.0      0      0   8.0500        S   Third    man   True
# ..      ...   ...    ...    ...      ...      ...     ...    ...    ...
# 886    male  27.0      0      0  13.0000        S  Second    man   True
# 887  female  19.0      0      0  30.0000        S   First  woman   True
# 888  female   NaN      1      2  23.4500        S   Third  woman  False
# 889    male  26.0      0      0  30.0000        C   First    man   True
# 890    male  32.0      0      0   7.7500        Q   Third    man   True
#
#      survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ...

# %%
cat=tdf.select_dtypes(include='object').columns
num=tdf.select_dtypes(exclude='object').columns

# %%
cat
# Out:
# Index(['sex', 'embarked', 'class', 'who'], dtype='object')

# %%
num
# Out:
# Index(['age', 'sibsp', 'parch', 'fare', 'alone', 'survived'], dtype='object')

# %%
k=tdf.isnull().sum()

# %%
k
# Out:
# sex           0
# age         177
# sibsp         0
# parch         0
# fare          0
# embarked      2
# class         0
# who           0
# alone         0
# survived      0
# dtype: int64

# %%
meany=tdf['age'].mean()
meany
# Out:
# 29.69911764705882

# %%
mediany=tdf['age'].median()
mediany
# Out:
# 28.0

# %%
modey=tdf['age'].mode
modey
# Out:
# <bound method Series.mode of 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64>

# %%
tdf['age']=tdf['age'].fillna(mediany)

# %%
tdf['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
tdf
# Out:
#         sex   age  sibsp  parch     fare embarked   class    who  alone  \
# 0      male  22.0      1      0   7.2500        S   Third    man  False
# 1    female  38.0      1      0  71.2833        C   First  woman  False
# 2    female  26.0      0      0   7.9250        S   Third  woman   True
# 3    female  35.0      1      0  53.1000        S   First  woman  False
# 4      male  35.0      0      0   8.0500        S   Third    man   True
# ..      ...   ...    ...    ...      ...      ...     ...    ...    ...
# 886    male  27.0      0      0  13.0000        S  Second    man   True
# 887  female  19.0      0      0  30.0000        S   First  woman   True
# 888  female  28.0      1      2  23.4500        S   Third  woman  False
# 889    male  26.0      0      0  30.0000        C   First    man   True
# 890    male  32.0      0      0   7.7500        Q   Third    man   True
#
#      survived
# 0           0  22.0
# 1           1  38.0
# 2           1  26.0
# 3           1  35.0
# ...

# %%
tdf['embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
tdf['embarked']=tdf['embarked'].fillna('Q')

# %%
tdf
# Out:
#         sex   age  sibsp  parch     fare embarked   class    who  alone  \
# 0      male  22.0      1      0   7.2500        S   Third    man  False
# 1    female  38.0      1      0  71.2833        C   First  woman  False
# 2    female  26.0      0      0   7.9250        S   Third  woman   True
# 3    female  35.0      1      0  53.1000        S   First  woman  False
# 4      male  35.0      0      0   8.0500        S   Third    man   True
# ..      ...   ...    ...    ...      ...      ...     ...    ...    ...
# 886    male  27.0      0      0  13.0000        S  Second    man   True
# 887  female  19.0      0      0  30.0000        S   First  woman   True
# 888  female  28.0      1      2  23.4500        S   Third  woman  False
# 889    male  26.0      0      0  30.0000        C   First    man   True
# 890    male  32.0      0      0   7.7500        Q   Third    man   True
#
#      survived
# 0           0  22.0
# 1           1  38.0
# 2           1  26.0
# 3           1  35.0
# ...

# %%
tdf.isnull().sum()
# Out:
# sex         0
# age         0
# sibsp       0
# parch       0
# fare        0
# embarked    0
# class       0
# who         0
# alone       0
# survived    0
#             0
# dtype: int64

# %%
tdf.loc[0:3]
# Out:
#       sex   age  sibsp  parch     fare embarked  class    who  alone  \
# 0    male  22.0      1      0   7.2500        S  Third    man  False
# 1  female  38.0      1      0  71.2833        C  First  woman  False
# 2  female  26.0      0      0   7.9250        S  Third  woman   True
# 3  female  35.0      1      0  53.1000        S  First  woman  False
#
#    survived
# 0         0  22.0
# 1         1  38.0
# 2         1  26.0
# 3         1  35.0

# %%
tdf.loc[0]
# Out:
# sex          male
# age          22.0
# sibsp           1
# parch           0
# fare         7.25
# embarked        S
# class       Third
# who           man
# alone       False
# survived        0
#              22.0
# Name: 0, dtype: object

# %%
tdf.loc[[0,7]]
# Out:
#     sex   age  sibsp  parch    fare embarked  class    who  alone  survived  \
# 0  male  22.0      1      0   7.250        S  Third    man  False         0
# 7  male   2.0      3      1  21.075        S  Third  child  False         0
#
#
# 0  22.0
# 7   2.0

# %%
tdf.iloc[0:3]
# Out:
#       sex   age  sibsp  parch     fare embarked  class    who  alone  \
# 0    male  22.0      1      0   7.2500        S  Third    man  False
# 1  female  38.0      1      0  71.2833        C  First  woman  False
# 2  female  26.0      0      0   7.9250        S  Third  woman   True
#
#    survived
# 0         0  22.0
# 1         1  38.0
# 2         1  26.0

# %%
tdf.iloc[0]
# Out:
# sex          male
# age          22.0
# sibsp           1
# parch           0
# fare         7.25
# embarked        S
# class       Third
# who           man
# alone       False
# survived        0
#              22.0
# Name: 0, dtype: object

# %%
tdf.iloc[[0,7]]
# Out:
#     sex   age  sibsp  parch    fare embarked  class    who  alone  survived  \
# 0  male  22.0      1      0   7.250        S  Third    man  False         0
# 7  male   2.0      3      1  21.075        S  Third  child  False         0
#
#
# 0  22.0
# 7   2.0

# %%
tdf.iloc[0,7]
# Out:
# 'man'

# %%
tdf.loc[200:300,['sex','age','class']]
# Out:
#         sex   age  class
# 200    male  28.0  Third
# 201    male  28.0  Third
# 202    male  34.0  Third
# 203    male  45.5  Third
# 204    male  18.0  Third
# ..      ...   ...    ...
# 296    male  23.5  Third
# 297  female   2.0  First
# 298    male  28.0  First
# 299  female  50.0  First
# 300  female  28.0  Third
#
# [101 rows x 3 columns]

# %%
tdf.iloc[200:300,[0,1]]
# Out:
#         sex   age
# 200    male  28.0
# 201    male  28.0
# 202    male  34.0
# 203    male  45.5
# 204    male  18.0
# ..      ...   ...
# 295    male  28.0
# 296    male  23.5
# 297  female   2.0
# 298    male  28.0
# 299  female  50.0
#
# [100 rows x 2 columns]

# %%
tdf['sex'].nunique()
# Out:
# 2

# %%
tdf['sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
cont_labels=tdf['sex'].unique()
count=[]
for i in cont_lables:
 tdf['sex']
 con=tdf['sex']==i
 tdf[con]
 count.append(len(tdf[con]))

# %%
cont_labels,count
# Out:
# (array(['male', 'female'], dtype=object), [577, 314])

# %%
cols=['sex','Number']
cont_df1=pd.DataFrame(zip(cont_labels,count),
 columns=cols)
cont_df1
# Out:
#       sex  Number
# 0    male     577
# 1  female     314

# %%
plt.bar(cont_df1['sex'],cont_df1['Number'])
# Out:
# <BarContainer object of 2 artists>

# %%
keys=tdf['sex'].value_counts().keys()
plt.figure(figsize=(10,5))
sns.countplot(data=tdf,
 x='sex',
 order=keys)
plt.title('Countplot')
# Out:
# Text(0.5, 1.0, 'Countplot')

# %%
cat
# Out:
# Index(['sex', 'embarked', 'class', 'who'], dtype='object')

# %%
plt.pie(count,labels=cont_labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x253a597f160>,
# ...
#  [Text(-0.4919454136803954, 0.9838646807152012, 'male'),
#   Text(0.4919455057964525, -0.9838646346559433, 'female')])

# %%
cont1=tdf['embarked'].unique()
count1=[]
for i in cont1:
 tdf['embarked']
 con=tdf['embarked']==i
 tdf[con]
 count1.append(len(tdf[con]))

# %%
cont1,count1
# Out:
# (array(['S', 'C', 'Q'], dtype=object), [644, 168, 79])

# %%
plt.pie(count1,labels=cont1)
# Out:
# ([<matplotlib.patches.Wedge at 0x253a5a6c610>,
# ...
#  [Text(-0.7085508191518028, 0.8414010557868996, 'S'),
#   Text(0.4498891527136986, -1.0037926829134345, 'C'),
#   Text(1.057601402809002, -0.30245540626087564, 'Q')])

# %%
cont2=tdf['class'].unique()
count2=[]
for i in cont2:
 tdf['class']
 con=tdf['class']==i
 tdf[con]
 count2.append(len(tdf[con]))

# %%
cont2,count2
# Out:
# (array(['Third', 'First', 'Second'], dtype=object), [491, 216, 184])

# %%
plt.pie(count2,labels=cont2)
# Out:
# ([<matplotlib.patches.Wedge at 0x253a5acf820>,
# ...
#  [Text(-0.17571616709359641, 1.0858746836637898, 'Third'),
#   Text(-0.5160762002061153, -0.9714243951954356, 'First'),
#   Text(0.8765111456658484, -0.6646263698677192, 'Second')])

# %%
cont3=tdf['who'].unique()
count3=[]
for i in cont3:
 tdf['who']
 con=tdf['who']==i
 tdf[con]
 count3.append(len(tdf[con]))

# %%
cont3,count3
# Out:
# (array(['man', 'woman', 'child'], dtype=object), [537, 271, 83])

# %%
plt.pie(count3,labels=cont3)
# Out:
# ([<matplotlib.patches.Wedge at 0x253a598b760>,
# ...
#  [Text(-0.3487593016911999, 1.0432482683828748, 'man'),
#   Text(0.03296249724279082, -1.0995060135240367, 'woman'),
#   Text(1.0532306714066144, -0.3173407518872612, 'child')])
