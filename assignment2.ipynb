# %%
#Ask the user to enter a number. Print out the square of the number,
#Sample output is shown below.
#Enter a number: 5
#The square of 5 is 25.

import random
n=random.randint(1,5)
m=pow(n,2)
print(m)
# Out:
# 16

# %%
#Ask the user to enter a number x. print out x, 2x, 3x, 4x, and 5x,
#each separated by three dashes, like below.
#Enter a number: 7
#7---14---21---28---35
import random
n=random.randint(1,5)
for i in range(1,6):
    print(n*i,sep=" ")
# Out:
# 3
# 6
# 9
# 12
# 15

# %%
#Write a program that asks the user for a weight in kilograms and converts it to pounds. There are 2.2 pounds in a kilogram.
import random
kg=random.randint(1,10)
print("pounds: ",kg*2.2)
# Out:
# pounds:  15.400000000000002

# %%
#Write a program that asks the user to enter three numbers (use threeseparate input statements).
#Create variables called total and 
#averagethat hold the sum and average of the three numbers and print out thevalues of total and average.
import random
a=random.randint(1,100)
b=random.randint(1,100)
c=random.randint(1,100)
total=a+b+c
avg=total/3
print("a: ",a,"b: ",b,"c: ",c,"total: ", total, "avg: ",avg)
# Out:
# a:  15 b:  96 c:  67 total:  178 avg:  59.333333333333336

# %%
#A lot of cell phones have tip calculators. Write one. Ask the user for
#the price of the meal and the percent tip they want to leave. Then
#print both the tip amount and the total bill with the tip included.
import random
bill_amount=random.randint(300,1000)
tip_percentage=random.randint(1,100)
print("bill_amount: ",bill_amount)
print("tip_percentage: ", tip_percentage)
tip_amount=bill_amount*tip_percentage/100
total_bill=tip_amount+bill_amount
print(f"the total bill is:{total_bill}")
# Out:
# bill_amount:  884
# tip_percentage:  45
# the total bill is:1281.8

# %%
#wap ask the user enter the 2 numbers find the subtraction,addition,multiplication and division
import random
a=random.randint(1,10)
b=random.randint(1,10)
print("a:",a)
print("b:", b)
add=a+b
sub=a-b
mul=a*b
div=a/b
print(f"addition: {add} , sub: {sub} , mul: {mul}, div: {div}")
# Out:
# a: 7
# b: 1
# addition: 8 , sub: 6 , mul: 7, div: 7.0

# %%
#wap ask the user enter radius values and pi value find the area of the circle
import random
pi=3.14
r=random.randint(1,10)
area=pi*r*r
print(f"area: {area}")
# Out:
# area: 153.86

# %%
#wap ask the user bill amount in dollars, ask the user enter howmuch indian rupees for one dollar print the bill amount in rupees
import random
n=random.randint(1,1000)
rup=83.46*n
print(f"amount in rupees: {rup}$")
# Out:
# amount in rupees: 67268.76$

# %%
# wap ask the user enter base height calculate area of the triangle
import random
base= random.randint(1,10)
height= random.randint(1,10)
area= (1/2)*base*height
print(f" the area of triangle= {area}")
# Out:
#  the area of triangle= 5.0

# %%
#wap ask the user enter length and breadth calculate area of the rectangle
import random
length=random.randint(1,10)
breadth=random.randint(1,10)
area= (length*length)+(breadth*breadth)
print(f"the area of rectangle: {area}")
# Out:
# the area of rectangle: 80

# %%
#Let’s create a story between Father and daughter , You need to
#create a story by using print and input keywords
#You need to develop a python code same like below steps
#The goal of this code is to understand python is step by step process
step1= input("father: ")
step2=input("daughter: ")
step3= input("father: ")
step4=input("daughter: ")
step5= input("father: ")
step6=input("daughter: ")
step7= input("father: ")
s1=random.randint(1,100)
s2= random.randint(1,100)
s3=random.randint(1,100)
s4=random.randint(1,100)
s5=random.randint(1,100)
print("s1:",s1)
print("s2:",s2)
print("s3:",s3)
print("s4:",s4)
print("s5:",s5)
step8=input("daughter: ")
step9= input("father: ")
total=s1+s2+s3+s4+s5
max =eval(input("daughter: "))
percentage=max/5
step10:print(f"father: your total is {total} and percentage is {percentage}")
# Out:
# father: hi dear
# daughter: hi daddy
# father: i hard that your exams are over. what about the results
# daughter: results are out dad
# father: then what is your percentage
# daughter: i will give you my subject wise marks ,please calculate the percentage dad
# father: oay
# s1: 49
# s2: 17
# s3: 83
# s4: 20
# s5: 72
# daughter: these are my marks dad calculate the percentage now
# father: what are max marks
# daughter: 100
# father: your total is 241 and percentage is 20.0
